# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Details/dataset/SentimentbasedRecoEngine/sample30.csv')
data.shape
# Out:
# (30000, 15)

# %%
data.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
#
#                          manufacturer  \
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# 3                                 K-Y
# 4                                 K-Y
#
#                                          name              reviews_date  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  2012-11-30T06:21:45.000Z
# ...

# %%
reviews = pd.read_excel('../Details/dataset/SentimentbasedRecoEngine/reviews_dataset.xlsx')
reviews.shape
# Out:
# (30000, 16)

# %%
reviews.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
#
#                          manufacturer  \
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# 3                                 K-Y
# 4                                 K-Y
#
#                                          name              reviews_date  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  2012-11-30T06:21:45.000Z
# ...

# %%
reviews.iloc[5414, :]
# Out:
# id                                                   AVpf0thK1cnluZ0-r8vR
# brand                                                        Warner Bros.
# categories              Movies, Music & Books,Movies,New Movie Release...
# manufacturer                                            Warner Home Video
# name                                  100:Complete First Season (blu-Ray)
# reviews_date                                     2014-11-04T00:00:00.000Z
# reviews_didPurchase                                                   NaN
# reviews_doRecommend                                                   1.0
# reviews_rating                                                          3
# reviews_text            Not bad for futuristic show. Has some shortcom...
# Unnamed: 10                                                           NaN
# reviews_title                 Not bad, better than I thought it would be.
# reviews_userCity                                                      NaN
# ...
